# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/sample_data/TMDB_all_movies.csv', engine='python')

df.head()
# Out:
#    id                             title  vote_average  vote_count    status  \
# 0   2                             Ariel           7.1       330.0  Released
# 1   3               Shadows in Paradise           7.3       369.0  Released
# 2   5                        Four Rooms           5.8      2623.0  Released
# 3   6                    Judgment Night           6.5       331.0  Released
# 4   8  Life in Loops (A Megacities RMX)           7.5        27.0  Released
#
#   release_date     revenue  runtime      budget    imdb_id  ...  \
# 0   1988-10-21         0.0     73.0         0.0  tt0094675  ...
# 1   1986-10-17         0.0     74.0         0.0  tt0092149  ...
# 2   1995-12-09   4257354.0     98.0   4000000.0  tt0113101  ...
# 3   1993-10-15  12136938.0    109.0  21000000.0  tt0107286  ...
# 4   2006-01-01         0.0     80.0     42000.0  tt0825671  ...
#
#                          spoken_languages  \
# 0                                   suomi
# ...

# %%
# recommendation will be based on these features only
df = df.loc[:,['title', 'vote_average', 'vote_count', 'release_date',
         'original_language', 'overview', 'popularity','genres','cast','imdb_id','imdb_rating', 'imdb_votes' ]]

# %%
df.isna().sum()
# Out:
# title                    11
# vote_average              2
# vote_count                2
# release_date         111166
# original_language         2
# overview             177061
# popularity                2
# genres               293199
# cast                 335202
# imdb_id              420513
# imdb_rating          580146
# imdb_votes           580146
# dtype: int64

# %%
df.dropna(subset=['title', 'genres','cast'], inplace=True)

# %%
df.isna().sum()
# Out:
# title                     0
# vote_average              0
# vote_count                0
# release_date          20143
# original_language         0
# overview              78389
# popularity                0
# genres                    0
# cast                      0
# imdb_id              142590
# imdb_rating          226388
# imdb_votes           226388
# dtype: int64

# %%
df.shape
# Out:
# (559119, 12)

# %%
df.dtypes
# Out:
# title                 object
# vote_average         float64
# vote_count           float64
# release_date          object
# original_language     object
# overview              object
# popularity           float64
# genres                object
# cast                  object
# imdb_id               object
# imdb_rating          float64
# imdb_votes           float64
# dtype: object

# %%
df.dropna(subset=['imdb_id', 'release_date'], inplace=True)

# %%
df.shape
# Out:
# (408169, 12)

# %%
df.isna().sum()
# Out:
# title                    0
# vote_average             0
# vote_count               0
# release_date             0
# original_language        0
# overview             40683
# popularity               0
# genres                   0
# cast                     0
# imdb_id                  0
# imdb_rating          76899
# imdb_votes           76899
# dtype: int64

# %%
df.dropna(subset=['overview', 'imdb_rating', 'imdb_votes'], inplace=True)

# %%
df.isna().sum()
# Out:
# title                0
# vote_average         0
# vote_count           0
# release_date         0
# original_language    0
# overview             0
# popularity           0
# genres               0
# cast                 0
# imdb_id              0
# imdb_rating          0
# imdb_votes           0
# dtype: int64

# %%
df.shape
# Out:
# (306589, 12)

# %%
df
# Out:
#                                                    title  vote_average  \
# 0                                                  Ariel           7.1
# 1                                    Shadows in Paradise           7.3
# 2                                             Four Rooms           5.8
# 3                                         Judgment Night           6.5
# 6                                              Star Wars           8.2
# ...                                                  ...           ...
# 1006877  Tell About the South: Voices in Black and White           0.0
# 1006879                                     Phantom Limb           0.0
# 1006893                          The Dragon In My Dreams           0.0
# 1006906                                   Bhalobasha 101           0.0
# 1006984                          Any Old Port in a Storm           0.0
#
#          vote_count release_date original_language  \
# 0             330.0   1988-10-21                fi
# ...

# %%
df['genres'] = df['genres'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# %%
df
# Out:
#                                                    title  vote_average  \
# 0                                                  Ariel           7.1
# 1                                    Shadows in Paradise           7.3
# 2                                             Four Rooms           5.8
# 3                                         Judgment Night           6.5
# 6                                              Star Wars           8.2
# ...                                                  ...           ...
# 1006877  Tell About the South: Voices in Black and White           0.0
# 1006879                                     Phantom Limb           0.0
# 1006893                          The Dragon In My Dreams           0.0
# 1006906                                   Bhalobasha 101           0.0
# 1006984                          Any Old Port in a Storm           0.0
#
#          vote_count release_date original_language  \
# 0             330.0   1988-10-21                fi
# ...

# %%
print(df['genres'].isnull().sum())
# Out:
# 0

# %%
df['cast'] = df['cast'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# %%
print(df['cast'].isnull().sum())
# Out:
# 0

# %%
df.to_csv('movie_data2.csv', index=False)
